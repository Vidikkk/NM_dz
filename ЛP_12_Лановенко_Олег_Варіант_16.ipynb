# %% [markdown]
# <a href="https://colab.research.google.com/github/Vidikkk/NM_dz/blob/main/%D0%9BP_12_%D0%9B%D0%B0%D0%BD%D0%BE%D0%B2%D0%B5%D0%BD%D0%BA%D0%BE_%D0%9E%D0%BB%D0%B5%D0%B3_%D0%92%D0%B0%D1%80%D1%96%D0%B0%D0%BD%D1%82_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторна робота 12
# Чисельне інтегрування
# Лановенко Олег
# ФІТ 2-10
# Варіант 16

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Завдання 1. Метод прямокутників (правих, лівих і середніх)

# %%
#Обчислення інтеграла методом прямокутників
from scipy import integrate
import numpy as np

a, b, n = 1.6, 2.2, 10

h = (b - a) / n  # Крок

def f1(x):
    #return 1/pow(x+2.5, 0.5)
    return 1/pow(x+2.5, 0.5)

# Метод лівих прямокутників
def left_rec(f1, a, b):
    sum = 0
    for i in range(0, n):
        sum += f1(a + i * h)
    return sum * h

print("Left rectangle:", round(left_rec(f1, a, b), 5))

# Метод правих прямокутників
def right_rec(f1, a, b):
    sum = 0
    for i in range(1, n+1):
        sum += f1(a + i * h)
    return sum * h

print("Right rectangle:", round(right_rec(f1, a, b), 5))

# Метод середніх прямокутників
def aver_rec(f1, a, b):
    sum = 0
    for i in range(0, n):
        sum += f1(a + (i + 0.5) * h)
    return sum * h

print("Average rectangle:", round(aver_rec(f1, a, b), 5))

# Перевірка за допомогою функції scipy
v, err = integrate.quad(f1, a, b)
print("Check with SciPy quad method:", round(v, 5))
# Out:
# Left rectangle: 0.28719
# Right rectangle: 0.28523
# Average rectangle: 0.2862
# Check with SciPy quad method: 0.28621

# %% [markdown]
# Завдання 2. Метод Симпсона

# %%
#Обчислення інтеграла методом Симпсона
from scipy import integrate
import numpy as np

# Задаємо функцію, яку необхідно інтегрувати
def f(x):
    return (pow(x,2) + 1) * np.sin(x-0.5)

# Задаємо межі інтегрування та початкову кількість розбиттів
a, b, n = 1.3, 2.1, 8

h = (b - a) / n

# Обчислюємо значення інтегралу методом Симпсона
def simpson_rule(f, a, b, n):
    integr = f(a) + f(b)
    for i in range(1,n):
        k = a + i*h
        if i%2 == 0:
            integr += 2 * f(k)
        else:
            integr += 4 * f(k)
    integr *= h/3
    return integr


# Виводимо результат
print("Simpsone method:", round(simpson_rule(f, a, b, n), 3))

v,err = integrate.quad(f,a,b)#Перевірка
print("Check for the simpsone method= ",round(v, 3))
# Out:
# Simpsone method: 2.913
# Check for the simpsone method=  2.913

# %% [markdown]
# Завдання 3. Визначити інтеграл методом трапецій

# %%
#Обчислення інтегралу методом трапецій

from scipy import integrate
import numpy as np

# Задаємо функцію, яку необхідно інтегрувати
def f(x):
    #return 1 / pow(pow(x,2) + 25, 0.5)
    return 1 / pow(pow(x,2) + 25, 0.5)

# Задаємо межі інтегрування та початкову кількість розбиттів
a, b, n = 0.8, 1.8, 20

# Обчислюємо значення інтегралу методом трапецій
def trapezoidal_rule(f, a, b, n):
    h = (b - a) / n
    sum = 0.5 * (f(a) + f(b))
    x = a

    for i in range(1, n):
        x += h
        sum += f(x)

    integral = h * sum

    return integral

# Виводимо результат методу трапецій
integral = trapezoidal_rule(f, a, b, n)
print("Trapetzia method result:", round(integral, 5))

# Перевірка за допомогою вбудованої функції
v, err = integrate.quad(f, a, b)
print("Check with SciPy quad method:", round(v, 5))
# Out:
# Trapetzia method result: 0.19332
# Check with SciPy quad method: 0.19332
